# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,5,150)
y = (x + 2.5)**2 + 7

# %%
plt.plot(x,y)
plt.show()

# %%
def dJ(theta):
    return 2*(x + 2.5)

# %%
def J(theta):
    return (x + 2.5)**2 + 7

# %%
def gradient descent(lr,theta):
    limit =  1e-7
    history_theta = [theta]
